# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
trainData = pd.read_csv('/kaggle/input/titanic/train.csv')
AgeAvrg = int(trainData['Age'].mean())
trainData['Age'] = trainData['Age'].fillna(AgeAvrg)
trainData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
trainData.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
trainData
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  29.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
trainData = pd.get_dummies(trainData, columns=['Sex', 'Embarked'])
trainData
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500           0         1
# 1           1       1  38.0      1      0  71.2833           1         0
# 2           1       3  26.0      0      0   7.9250           1         0
# 3           1       1  35.0      1      0  53.1000           1         0
# 4           0       3  35.0      0      0   8.0500           0         1
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000           0         1
# 887         1       1  19.0      0      0  30.0000           1         0
# 888         0       3  29.0      1      2  23.4500           1         0
# 889         1       1  26.0      0      0  30.0000           0         1
# 890         0       3  32.0      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# ...

# %%
X = trainData.drop('Survived', axis=1) 
Y = trainData['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
            X, Y, test_size=0.1, random_state=42
)
X_train
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#      Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  Embarked_C  \
# 165       3   9.0      0      2   20.5250           0         1           0
# 541       3   9.0      4      2   31.2750           1         0           0
# 625       1  61.0      0      0   32.3208           0         1           0
# 388       3  29.0      0      0    7.7292           0         1           0
# 76        3  29.0      0      0    7.8958           0         1           0
# ..      ...   ...    ...    ...       ...         ...       ...         ...
# 106       3  21.0      0      0    7.6500           1         0           0
# 270       1  29.0      0      0   31.0000           0         1           0
# ...

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(X_train.values,Y_train.values)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
Y_predict = reg.predict(X_test.values)
Y_predict_binary = [1 if predidct > 0.5 else 0 for predidct in Y_predict]

# %%
from sklearn.metrics import r2_score

evaluate = r2_score(Y_test,Y_predict_binary)
evaluate
# Out:
# 0.2592592592592593
