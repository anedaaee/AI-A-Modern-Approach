# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

trainData = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
trainData.drop(['Id'], axis=1, inplace=True)
trainData['LotFrontage'].fillna(trainData['LotFrontage'].mean(), inplace=True)
trainData = pd.get_dummies(trainData, drop_first=True)
trainData.fillna(0,inplace=True)
trainData
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
X = trainData.drop('SalePrice', axis=1)  # Features (independent variables)
Y = trainData['SalePrice']
X
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 907           50         86.0    11500            7            7       1936
# 782           20         67.0    16285            7            5       2001
# 952           85         60.0     7200            5            8       1972
# 620           30         45.0     8248            3            3       1914
# 669           30         80.0    11600            4            5       1922
# ...          ...          ...      ...          ...          ...        ...
# 1095          20         78.0     9317            6            5       2006
# 1130          50         65.0     7804            4            3       1928
# 1294          20         60.0     8172            5            7       1955
# 860           50         55.0     7642            7            8       1918
# 1126         120         53.0     3684            7            5       2007
#
# ...

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test.values)
Y_predict
# Out:
# array([155682.69318901, 339808.34178598,  89754.51716351, 178474.75598909,
#        320658.72948527,  70529.24191105, 231436.23188111, 146517.17533447,
#         66846.1928391 , 149077.30814583, 147050.96244966, 103761.51797989,
#         64710.78995784, 223278.51368728, 172243.47536023, 128681.73951466,
#        187021.66226424, 119760.072795  , 135779.57412832, 214034.54433385,
#        154580.83271151, 204564.47999008, 174794.24496303, 129529.07548402,
#        201323.01614553, 142845.09160858, 198600.15828734, 107538.71046959,
#        177196.41593791, 200431.03265752, 149335.0013719 , 281654.80391424,
#        247478.95461308, 110652.07659795, 238719.80074644, 149301.49450088,
#        140934.75317838, 200707.46348064, 309102.03629295, 123885.76469969,
#        120856.7750923 , 221744.92195126,  99195.88953041, 375343.41731729,
#        132784.22404351, 137691.28716807,  90434.01925543, 139092.73374094,
# ...

# %%
from sklearn.metrics import r2_score

evaluate = r2_score(Y_test,Y_predict)
evaluate
# Out:
# 0.8955878294864992
